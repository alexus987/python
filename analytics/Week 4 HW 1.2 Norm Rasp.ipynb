# %% [markdown]
# ## Домашняя работа

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
# %matplotlib inline

# %%
# зададим нормально распределенную случайную величину
norm_rv = sts.norm(0, 1)
sample = norm_rv.rvs(1000)

# %%
x = np.linspace(0,50,1000)
for k in [5, 10, 50]:
    rv = sts.chi2(k)
    cdf = rv.cdf(x)
    plt.plot(x, cdf, label="$k=%s$" % k)
    
plt.legend()

# %%
#Гистограмма выборки:
plt.hist(cdf,  bins=10, normed=True)
plt.ylabel('number of samples')
plt.xlabel('$x$')

# %% [markdown]
# Эмпирическая оценка плотности, построенная по выборке с помощью ядерного сглаживания:

# %%
# для построения используем библиотеку Pandas:
df = pd.DataFrame(sample, columns=['KDE'])
ax = df.plot(kind='density')

# на том же графике построим теоретическую плотность распределения:
x = np.linspace(-4,4,100)
pdf = norm_rv.pdf(x)
plt.plot(x, pdf, label='theoretical pdf', alpha=0.5)
plt.legend()
plt.ylabel('$f(x)$')
plt.xlabel('$x$')

# %%
# для построения используем библиотеку Pandas:
df = pd.DataFrame(x, columns=['KDE'])
ax = df.plot(kind='density')

# на том же графике построим теоретическую плотность распределения:
x = np.linspace(0,50,1000)
for k in [5, 10, 50]:
    rv = sts.chi2(k)
    pdf = rv.pdf(x)
    #plt.plot(x, cdf, label="$k=%s$" % k)
#pdf = norm_rv.pdf(x)
plt.plot(x, pdf, label='theoretical pdf', alpha=0.5)
plt.legend()
plt.ylabel('$f(x)$')
plt.xlabel('$x$')

# %%
#Эмпирическая функция распределения для полученной выборки:
plt.plot(x, cdf, label='theoretical CDF')

# для построения ECDF используем библиотеку statsmodels
from statsmodels.distributions.empirical_distribution import ECDF
ecdf = ECDF(x)
plt.step(ecdf.x, ecdf.y, label='ECDF')

plt.ylabel('$f(x)$')
plt.xlabel('$x$')
plt.legend(loc='upper left')

# %% [markdown]
# ##### Моё любимое непрерывное распределение - хи-квадрат $\chi^2_k$

# %%
#Сгенерируйте из него выборку объёма 1000
x = np.linspace(0,50,1000)
rv = sts.chi2(x)

#Построим график функции распределения:
for k in [5, 10, 50]:
    rv = sts.chi2(k)
    cdf = rv.cdf(x)
    plt.plot(x, cdf, label="$k=%s$" % k)
plt.legend()
plt.title("CDF ($\chi^2_k$)")
plt.ylabel('$F(x)$')
plt.xlabel('$x$')

# %%
#и теоретическую плотность распределения вашей случайной величины
cdf = rv.cdf(x)
plt.plot(x, cdf)
plt.title("CDF ($\chi^2_k$)")
plt.ylabel('$F(x)$')
plt.xlabel('$x$')

# %%
#Tеоретическую плотность распределения вашей случайной величины
norm_rv.pdf(x)
#Построим график функции плотности вероятности:
x = np.linspace(0,50,1000)
pdf = norm_rv.pdf(x)
plt.plot(x, pdf)
plt.title("CDF ($\chi^2_k$)")
plt.ylabel('$f(x)$')
plt.xlabel('$x$')

# %%
#при трёх и более значениях n (например, 5, 10, 50) сгенерируйте 1000 выборок объёма n 
x = np.linspace(0,50,1000)
for k in [5, 10, 50]:
    rv = sts.chi2(k)
    cdf = rv.cdf(x)
    plt.plot(x, cdf, label="$k=%s$" % k)
plt.legend()
plt.title("CDF ($\chi^2_k$)")
